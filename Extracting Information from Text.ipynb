# %%
import nltk
nltk.download()
# Out:
# /home/monu/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
import docx
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
        return '\\n'.join(fullText)

# %%
filename = ( '/home/monu/Desktop/job1.txt')
file = open(filename, 'rt')
document =file.read()
file.close()

# %%
print(document)
# Out:
# ﻿Company Job Offer Letter
# [Date:01/01/2019]
# Ms. (Monu kumar)
# (Address)
# (Banglore, karnataka, 800002)
# Dear Ms. (Monu kumar):
# [FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization. We are excited about the potential that you bring to our company.
# As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located. You will report directly to the Vice-President of Operations and be a member of our Executive Management Team. After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.
# ...

# %%
import re
lines_ini = re.split('    |\\n',document)
lines_ini = [el.strip(',') for el in lines_ini]

# %%
print(lines_ini)
# Out:
# ['\ufeffCompany\xa0Job\xa0Offer Letter', '[Date:01/01/2019]', 'Ms. (Monu kumar)', '(Address)', '(Banglore, karnataka, 800002)', 'Dear Ms. (Monu kumar):', '[FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization. We are excited about the potential that you bring to our company.', "As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located. You will report directly to the Vice-President of Operations and be a member of our Executive Management Team. After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.", "You will be classified as an exempt executive-level employee. Your initial compensation package includes a weekly salary
# ...

# %%
project=[0]
project=" data=''\ufeffCompany\xa0Job\xa0Offer Letter', '[Date:01/01/2019]', 'Ms. (Monu kumar)', '(Address)', '(Banglore, karnataka, 800002)', 'Dear Ms. (Monu kumar):', '[FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization. We are excited about the potential that you bring to our company.', "As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located. You will report directly to the Vice-President of Operations and be a member of our Executive Management Team. After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.", "You will be classified as an exempt executive-level employee. Your initial compensation package includes a weekly salary of $1600 (payable biweekly), full medical and dental coverage through our company's employee benefit plan, and fringe benefits as covered in the enclosed pamphlet. [If applicable, the following provision can be added: In addition, [name of company] will loan you an amount equal to all of your reasonable expenses of relocation, including [not including] seller's commission on your old residence and closing costs on your new residence [, plus an additional amount of $(amount) to help you handle miscellaneous unanticipated costs*]. Should you remain with the company at least three years, the loan amount will be forgiven in its entirety. Advances of the loan amount and any repayment of the loan will be according to the schedule in the enclosed agreement, a signed copy of which you should return by mail prior to incurring any relocation expenses.]", 'In accepting our offer of employment, you certify your understanding that your employment will be on an at-will basis, and that neither you nor any Company representative have entered into a contract regarding the terms or the duration of your employment. As an at-will employee, you will be free to terminate your employment with the Company at any time, with or without cause or advance notice. Likewise, the Company will have the right to reassign you, to change your compensation, or to terminate your employment at any time, with or without cause or advance notice.', "We look forward to your arrival at our company and are confident that you will play a key role in our company's expansion into national and international markets. Please let me know if you have any questions or if I can do anything to make your arrival easier.", 'Sincerely', '_________________________', '[RAJ]', 'Senior Vice-President', '[FACEBOOK]''"
# Out:
#   File "<ipython-input-8-0fefd96c06b4>", line 2
# ...

# %%
m="Company Job Offer Letter[Date:01/01/2019]Ms. (Monu kumar)(Address)(Banglore, karnataka, 800002)Dear Ms. (Monu kumar):[FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization. We are excited about the potential that you bring to our company.As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located. You will report directly to the Vice-President of Operations and be a member of our Executive Management Team. After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.You will be classified as an exempt executive-level employee. Your initial compensation package includes a weekly salary of $1600 (payable biweekly), full medical and dental coverage through our company's employee benefit plan, and fringe benefits as covered in the enclosed pamphlet. [If applicable, the following provision can be added: In addition, [name of company] will loan you an amount equal to all of your reasonable expenses of relocation, including [not including] seller's commission on your old residence and closing costs on your new residence [, plus an additional amount of $(amount) to help you handle miscellaneous unanticipated costs*]. Should you remain with the company at least three years, the loan amount will be forgiven in its entirety. Advances of the loan amount and any repayment of the loan will be according to the schedule in the enclosed agreement, a signed copy of which you should return by mail prior to incurring any relocation expenses.]In accepting our offer of employment, you certify your understanding that your employment will be on an at-will basis, and that neither you nor any Company representative have entered into a contract regarding the terms or the duration of your employment. As an at-will employee, you will be free to terminate your employment with the Company at any time, with or without cause or advance notice. Likewise, the Company will have the right to reassign you, to change your compensation, or to terminate your employment at any time, with or without cause or advance notice.We look forward to your arrival at our company and are confident that you will play a key role in our company's expansion into national and international markets. Please let me know if you have any questions or if I can do anything to make your arrival easier.Sincerely,_________________________[RAJ]Senior Vice-President[FACEBOOK]"

# %%
m
# Out:
# "Company\xa0Job\xa0Offer Letter[Date:01/01/2019]Ms. (Monu kumar)(Address)(Banglore, karnataka, 800002)Dear Ms. (Monu kumar):[FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization. We are excited about the potential that you bring to our company.As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located. You will report directly to the Vice-President of Operations and be a member of our Executive Management Team. After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.You will be classified as an exempt executive-level employee. Your initial compensation package includes a weekly salary of $1600 (payable biweekly), full medi
# ...

# %%
type(m)
# Out:
# str

# %%
len(m)
# Out:
# 2708

# %%
from nltk.probability import FreqDist
fdist=FreqDist()

# %%
from nltk.tokenize import word_tokenize

# %%
m_token=word_tokenize(m)
m_token
# Out:
# ['Company',
#  'Job',
#  'Offer',
#  'Letter',
#  '[',
#  'Date:01/01/2019',
#  ']',
#  'Ms.',
#  '(',
#  'Monu',
#  'kumar',
#  ')',
#  '(',
#  'Address',
#  ')',
#  '(',
#  'Banglore',
#  ',',
#  'karnataka',
#  ',',
#  '800002',
#  ')',
#  'Dear',
#  'Ms.',
#  '(',
#  'Monu',
#  'kumar',
#  ')',
#  ':',
#  '[',
#  'FACEBOOK',
#  ']',
#  'is',
#  'pleased',
#  'to',
#  'offer',
#  'you',
#  'the',
#  'position',
#  'of',
#  'DATA',
#  'SCIENTIST',
#  'for',
#  'our',
#  'organization',
#  '.',
#  'We',
#  'are',
#  'excited',
#  'about',
#  'the',
#  'potential',
#  'that',
#  'you',
#  'bring',
#  'to',
#  'our',
#  'company.As',
#  'we',
#  'discussed',
#  'during',
#  'your',
#  'interviews',
#  ',',
#  'you',
#  'will',
#  'be',
#  'working',
#  'in',
#  'our',
#  'north',
#  '[',
#  'city',
#  ']',
#  'regional',
#  'office',
#  ',',
#  'where',
#  'our',
#  'DATA',
#  'and',
#  'customer',
#  'service',
#  'departments',
#  'are',
#  'located',
#  '.',
#  'You',
#  'will',
# ...

# %%
len(m_token)
# Out:
# 500

# %%
from nltk.probability import FreqDist
fdist=FreqDist()

# %%
for word in m_token:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 23, 'the': 16, 'your': 15, 'to': 14, 'you': 14, 'of': 13, 'will': 13, 'our': 11, '.': 11, 'company': 10, ...})

# %%
fdist
# Out:
# FreqDist({',': 23, 'the': 16, 'your': 15, 'to': 14, 'you': 14, 'of': 13, 'will': 13, 'our': 11, '.': 11, 'company': 10, ...})

# %%
m
# Out:
# "Company\xa0Job\xa0Offer Letter[Date:01/01/2019]Ms. (Monu kumar)(Address)(Banglore, karnataka, 800002)Dear Ms. (Monu kumar):[FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization. We are excited about the potential that you bring to our company.As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located. You will report directly to the Vice-President of Operations and be a member of our Executive Management Team. After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.You will be classified as an exempt executive-level employee. Your initial compensation package includes a weekly salary of $1600 (payable biweekly), full medi
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words("english"))
a = word_tokenize(m)

# %%
for word in a:
    if word not in stop_words:
        print(word)
# Out:
# Company
# Job
# Offer
# Letter
# [
# Date:01/01/2019
# ]
# Ms.
# (
# Monu
# kumar
# )
# (
# Address
# )
# (
# Banglore
# ,
# karnataka
# ,
# 800002
# )
# Dear
# Ms.
# (
# Monu
# kumar
# )
# :
# [
# FACEBOOK
# ]
# pleased
# offer
# position
# DATA
# SCIENTIST
# organization
# .
# We
# excited
# potential
# bring
# company.As
# discussed
# interviews
# ,
# working
# north
# [
# city
# ]
# regional
# office
# ,
# DATA
# customer
# service
# departments
# located
# .
# You
# report
# directly
# Vice-President
# Operations
# member
# Executive
# Management
# Team
# .
# After
# finishing
# orientation
# new
# executives
# ,
# initial
# task
# help
# recruit
# train
# new
# marketing
# staff
# focused
# developing
# company
# 's
# e-commerce
# division
# ,
# many
# projects
# associated
# overall
# marketing
# efforts
# need
# attention.You
# classified
# exempt
# executive-level
# employee
# .
# Your
# initial
# compensation
# package
# includes
# weekly
# salary
# $
# 1600
# (
# payable
# ...

# %%
word1="CompanyJobOfferLetter[Date:01/01/2019]Ms.(Monukumar)(Address)(Banglore,karnataka,800002)DearMs.(Monukumar):[FACEBOOK]pleasedofferpositionDATASCIENTISTorganization.Weexcitedpotentialbringcompany.Asdiscussedinterviews,workingnorth[city]regionaloffice,DATAcustomerservicedepartmentslocated.YoureportdirectlyVice-PresidentOperationsmemberExecutiveManagementTeam.Afterfinishingorientationnewexecutives,initialtaskhelprecruittrainnewmarketingstafffocuseddevelopingcompany'se-commercedivision,manyprojectsassociatedoverallmarketingeffortsneedattention.Youclassifiedexemptexecutive-levelemployee.Yourinitialcompensationpackageincludesweeklysalary$1600(payablebiweekly),fullmedicaldentalcoveragecompany'semployeebenefitplan,fringebenefitscoveredenclosedpamphlet.[Ifapplicable,followingprovisionadded:Inaddition,[namecompany]loanamountequalreasonableexpensesrelocation,including[including]seller'scommissionoldresidenceclosingcostsnewresidence[,plusadditionalamount$(amount)helphandlemiscellaneousunanticipatedcosts*].Shouldremaincompanyleastthreeyears,loanamountforgivenentirety.Advancesloanamountrepaymentloanaccordingscheduleenclosedagreement,signedcopyreturnmailpriorincurringrelocationexpenses.]Inacceptingofferemployment,certifyunderstandingemploymentat-willbasis,neitherCompanyrepresentativeenteredcontractregardingtermsdurationemployment.Asat-willemployee,freeterminateemploymentCompanytime,withoutcauseadvancenotice.Likewise,Companyrightreassign,changecompensation,terminateemploymenttime,withoutcauseadvancenotice.Welookforwardarrivalcompanyconfidentplaykeyrolecompany'sexpansionnationalinternationalmarkets.PleaseletknowquestionsIanythingmakearrivaleasier.Sincerely,_________________________[RAJ]SeniorVice-President[FACEBOOK]"

# %%
word1
# Out:
# "CompanyJobOfferLetter[Date:01/01/2019]Ms.(Monukumar)(Address)(Banglore,karnataka,800002)DearMs.(Monukumar):[FACEBOOK]pleasedofferpositionDATASCIENTISTorganization.Weexcitedpotentialbringcompany.Asdiscussedinterviews,workingnorth[city]regionaloffice,DATAcustomerservicedepartmentslocated.YoureportdirectlyVice-PresidentOperationsmemberExecutiveManagementTeam.Afterfinishingorientationnewexecutives,initialtaskhelprecruittrainnewmarketingstafffocuseddevelopingcompany'se-commercedivision,manyprojectsassociatedoverallmarketingeffortsneedattention.Youclassifiedexemptexecutive-levelemployee.Yourinitialcompensationpackageincludesweeklysalary$1600(payablebiweekly),fullmedicaldentalcoveragecompany'semployeebenefitplan,fringebenefitscoveredenclosedpamphlet.[Ifapplicable,followingprovisionadded:Inaddition,[namecompany]loanamountequalreasonableexpensesrelocation,including[including]seller'scommissionoldresidenceclosingcostsnewresidence[,plusadditionalamount$(amount)helphandlemiscellaneousunanticipa
# ...

# %%
 import nltk
sentences = [nltk.pos_tag(sent) for sent in word1]

# %%
sentences
# Out:
# [[('C', 'SYM')],
#  [('o', 'NN')],
#  [('m', 'NN')],
#  [('p', 'NN')],
#  [('a', 'DT')],
#  [('n', 'NN')],
#  [('y', 'NN')],
#  [('J', 'NN')],
#  [('o', 'NN')],
#  [('b', 'NN')],
#  [('O', 'NN')],
#  [('f', 'NN')],
#  [('f', 'NN')],
#  [('e', 'NN')],
#  [('r', 'NN')],
#  [('L', 'NN')],
#  [('e', 'NN')],
#  [('t', 'NN')],
#  [('t', 'NN')],
#  [('e', 'NN')],
#  [('r', 'NN')],
#  [('[', 'NN')],
#  [('D', 'NN')],
#  [('a', 'DT')],
#  [('t', 'NN')],
#  [('e', 'NN')],
#  [(':', ':')],
#  [('0', 'CD')],
#  [('1', 'CD')],
#  [('/', 'NN')],
#  [('0', 'CD')],
#  [('1', 'CD')],
#  [('/', 'NN')],
#  [('2', 'CD')],
#  [('0', 'CD')],
#  [('1', 'CD')],
#  [('9', 'CD')],
#  [(']', 'NN')],
#  [('M', 'NN')],
#  [('s', 'NN')],
#  [('.', '.')],
#  [('(', '(')],
#  [('M', 'NN')],
#  [('o', 'NN')],
#  [('n', 'NN')],
#  [('u', 'NN')],
#  [('k', 'NN')],
#  [('u', 'NN')],
#  [('m', 'NN')],
#  [('a', 'DT')],
#  [('r', 'NN')],
#  [(')', ')')],
#  [('(', '(')],
#  [('A', 'DT')],
#  [('d', 'NN')],
# ...

# %%
a
# Out:
# ['Company',
#  'Job',
#  'Offer',
#  'Letter',
#  '[',
#  'Date:01/01/2019',
#  ']',
#  'Ms.',
#  '(',
#  'Monu',
#  'kumar',
#  ')',
#  '(',
#  'Address',
#  ')',
#  '(',
#  'Banglore',
#  ',',
#  'karnataka',
#  ',',
#  '800002',
#  ')',
#  'Dear',
#  'Ms.',
#  '(',
#  'Monu',
#  'kumar',
#  ')',
#  ':',
#  '[',
#  'FACEBOOK',
#  ']',
#  'is',
#  'pleased',
#  'to',
#  'offer',
#  'you',
#  'the',
#  'position',
#  'of',
#  'DATA',
#  'SCIENTIST',
#  'for',
#  'our',
#  'organization',
#  '.',
#  'We',
#  'are',
#  'excited',
#  'about',
#  'the',
#  'potential',
#  'that',
#  'you',
#  'bring',
#  'to',
#  'our',
#  'company.As',
#  'we',
#  'discussed',
#  'during',
#  'your',
#  'interviews',
#  ',',
#  'you',
#  'will',
#  'be',
#  'working',
#  'in',
#  'our',
#  'north',
#  '[',
#  'city',
#  ']',
#  'regional',
#  'office',
#  ',',
#  'where',
#  'our',
#  'DATA',
#  'and',
#  'customer',
#  'service',
#  'departments',
#  'are',
#  'located',
#  '.',
#  'You',
#  'will',
# ...

# %%
import nltk
sentences = [nltk.pos_tag(sent) for sent in a]

# %%
sentences
# Out:
# [[('C', 'NNP'),
#   ('o', 'MD'),
#   ('m', 'VB'),
#   ('p', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('y', 'NN')],
#  [('J', 'NNP'), ('o', 'NN'), ('b', 'NN')],
#  [('O', 'NNP'), ('f', 'NN'), ('f', 'NN'), ('e', 'NN'), ('r', 'NN')],
#  [('L', 'NNP'),
#   ('e', 'NN'),
#   ('t', 'NN'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN')],
#  [('[', 'NN')],
#  [('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'JJ'),
#   ('e', 'NN'),
#   (':', ':'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('/', 'NN'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('/', 'NN'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('9', 'CD')],
#  [(']', 'NN')],
#  [('M', 'NNP'), ('s', 'NN'), ('.', '.')],
#  [('(', '(')],
#  [('M', 'NNP'), ('o', 'MD'), ('n', 'VB'), ('u', 'JJ')],
#  [('k', 'NN'), ('u', 'JJ'), ('m', 'NN'), ('a', 'DT'), ('r', 'NN')],
#  [(')', ')')],
#  [('(', '(')],
#  [('A', 'DT'),
#   ('d', 'NN'),
#   ('d', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('s', 'NN')],
#  [(')', ')')],
# ...

# %%
    sentences = nltk.sent_tokenize(document)

# %%
sentences
# Out:
# ['\ufeffCompany\xa0Job\xa0Offer Letter\n[Date:01/01/2019]\nMs. (Monu kumar)\n(Address)\n(Banglore, karnataka, 800002)\nDear Ms. (Monu kumar):\n[FACEBOOK] is pleased to offer you the position of DATA SCIENTIST for our organization.',
#  'We are excited about the potential that you bring to our company.',
#  'As we discussed during your interviews, you will be working in our north [city] regional office, where our DATA and customer service departments are located.',
#  'You will report directly to the Vice-President of Operations and be a member of our Executive Management Team.',
#  "After finishing orientation for new executives, your initial task will be to help recruit and train a new marketing staff focused on developing our company's e-commerce division, but there will be many other projects associated with our overall marketing efforts that will need your attention.",
#  'You will be classified as an exempt executive-level employee.',
# ...

# %%
sentences = nltk.sent_tokenize(m)
sentences = [nltk.word_tokenize(sent) for sent in sentences] 
sentences = [nltk.pos_tag(sent) for sent in sentences]

# %%
sentences
# Out:
# [[('Company', 'NN'),
#   ('Job', 'NNP'),
#   ('Offer', 'NNP'),
#   ('Letter', 'NNP'),
#   ('[', 'NNP'),
#   ('Date:01/01/2019', 'NNP'),
#   (']', 'NNP'),
#   ('Ms.', 'NNP'),
#   ('(', '('),
#   ('Monu', 'NNP'),
#   ('kumar', 'NN'),
#   (')', ')'),
#   ('(', '('),
#   ('Address', 'NNP'),
#   (')', ')'),
#   ('(', '('),
#   ('Banglore', 'NNP'),
#   (',', ','),
#   ('karnataka', 'NNP'),
#   (',', ','),
#   ('800002', 'CD'),
#   (')', ')'),
#   ('Dear', 'IN'),
#   ('Ms.', 'NNP'),
#   ('(', '('),
#   ('Monu', 'NNP'),
#   ('kumar', 'NN'),
#   (')', ')'),
#   (':', ':'),
#   ('[', 'JJ'),
#   ('FACEBOOK', 'NNP'),
#   (']', 'NNP'),
#   ('is', 'VBZ'),
#   ('pleased', 'VBN'),
#   ('to', 'TO'),
#   ('offer', 'VB'),
#   ('you', 'PRP'),
#   ('the', 'DT'),
#   ('position', 'NN'),
#   ('of', 'IN'),
#   ('DATA', 'NNP'),
#   ('SCIENTIST', 'NNP'),
#   ('for', 'IN'),
#   ('our', 'PRP$'),
#   ('organization', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('are', 'VBP'),
#   ('excited', 'VBN'),
# ...

# %%
import nltk, re
sentence=[('Company', 'NN'),('Job', 'NNP'),('Offer', 'NNP'),('Letter', 'NNP'),('Date:01/01/2019', 'NNP'),('Ms.', 'NNP'),('Monu', 'NNP'),('kumar', 'NN'),('Address', 'NNP'),('Banglore', 'NNP'), ('karnataka', 'NNP'),('Dear', 'IN'), ('Ms.', 'NNP'),('Monu', 'NNP'),('kumar', 'NN'),('FACEBOOK', 'NNP'),('is', 'VBZ'),('pleased', 'VBN'),('to', 'TO'),('offer', 'VB'),('you', 'PRP'),('the', 'DT'),('position', 'NN'),('of', 'IN'),('DATA', 'NNP'),('SCIENTIST', 'NNP'),('for', 'IN'),('our', 'PRP$'),('organization', 'NN'),('We', 'PRP'),('are', 'VBP'),('excited', 'VBN'),('about', 'IN'),('the', 'DT'),('potential', 'NN'),('that', 'IN'),('you', 'PRP'),('bring', 'VBP'),('to', 'TO'),('our', 'PRP$'),('company.As', 'NN'),('we', 'PRP'),('discussed', 'VBD'),('during', 'IN'),('your', 'PRP$'),('interviews', 'NNS'),('you', 'PRP'),('will', 'MD'),('be', 'VB'),('working', 'VBG'),('in', 'IN'),('our', 'PRP$'),('north', 'JJ'),('city', 'NN'),('regional', 'JJ'),('office', 'NN'),('where', 'WRB'),('our', 'PRP$'),('DATA', 'NNP'),('and', 'CC'),('customer', 'NN'),('service', 'NN'),('departments', 'NNS'),('are', 'VBP'),('located', 'VBN'),('You', 'PRP'),('will', 'MD'),('report', 'VB'),('directly', 'RB'),('to', 'TO'),('the', 'DT'),('Vice-President', 'NNP'),('of', 'IN'),('Operations', 'NNP'),('and', 'CC'),('be', 'VB'),('a', 'DT'),('member', 'NN'),('of', 'IN'),('our', 'PRP$'),('Executive', 'NNP'),('Management', 'NNP'),('Team', 'NNP'),('After', 'IN'),('finishing', 'VBG'),('orientation', 'NN'),('for', 'IN'),('new', 'JJ'),('executives', 'NNS'),('your', 'PRP$'),('initial', 'JJ'),('task', 'NN'),('will', 'MD'),('be', 'VB'),('to', 'TO'),('help', 'VB'),('recruit', 'NN'),('and', 'CC'),('train', 'VB'),('a', 'DT'),('new', 'JJ'),('marketing', 'NN'),('staff', 'NN'),('focused', 'VBN'),('on', 'IN'),('developing', 'VBG'),('our', 'PRP$'),('company', 'NN'),("'s", 'POS'),('e-commerce', 'JJ'),('division', 'NN'),('but', 'CC'),('there', 'EX'),('will', 'MD'),('be', 'VB'),('many', 'JJ'),('other', 'JJ'),('projects', 'NNS'),('associated', 'VBN'),('with', 'IN'),('our', 'PRP$'),('overall', 'JJ'),('marketing', 'NN'),('efforts', 'NNS'),('that', 'WDT'),('will', 'MD'),('need', 'VB'),('your', 'PRP$'),('attention.You', 'NN'),('RAJ', 'NNP'),('Senior', 'NNP'),('Vice-President', 'NNP'),('FACEBOOK', 'NNP')]
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp = nltk.RegexpParser(grammar)
result = cp.parse(sentence)
print(result)
result.draw()
# Out:
# (S
#   (NP Company/NN)
#   Job/NNP
#   Offer/NNP
#   Letter/NNP
#   Date:01/01/2019/NNP
#   Ms./NNP
#   Monu/NNP
#   (NP kumar/NN)
#   Address/NNP
#   Banglore/NNP
#   karnataka/NNP
#   Dear/IN
#   Ms./NNP
#   Monu/NNP
#   (NP kumar/NN)
#   FACEBOOK/NNP
#   is/VBZ
#   pleased/VBN
#   to/TO
#   offer/VB
#   you/PRP
#   (NP the/DT position/NN)
#   of/IN
#   DATA/NNP
#   SCIENTIST/NNP
#   for/IN
#   our/PRP$
#   (NP organization/NN)
#   We/PRP
#   are/VBP
#   excited/VBN
#   about/IN
#   (NP the/DT potential/NN)
#   that/IN
#   you/PRP
#   bring/VBP
#   to/TO
#   our/PRP$
#   (NP company.As/NN)
#   we/PRP
#   discussed/VBD
#   during/IN
#   your/PRP$
#   interviews/NNS
#   you/PRP
#   will/MD
#   be/VB
#   working/VBG
#   in/IN
#   our/PRP$
#   (NP north/JJ city/NN)
#   (NP regional/JJ office/NN)
#   where/WRB
#   our/PRP$
#   DATA/NNP
#   and/CC
#   (NP customer/NN)
#   (NP service/NN)
#   departments/NNS
#   are/VBP
#   located/VBN
#   You/PRP
#   will/MD
#   report/VB
# ...

# %%
grammar = "NP: {<NN><NN>}"
cp = nltk.RegexpParser(grammar)
print(cp.parse(result))
# Out:
# (S
#   (NP Company/NN)
#   Job/NNP
#   Offer/NNP
#   Letter/NNP
#   Date:01/01/2019/NNP
#   Ms./NNP
#   Monu/NNP
#   (NP kumar/NN)
#   Address/NNP
#   Banglore/NNP
#   karnataka/NNP
#   Dear/IN
#   Ms./NNP
#   Monu/NNP
#   (NP kumar/NN)
#   FACEBOOK/NNP
#   is/VBZ
#   pleased/VBN
#   to/TO
#   offer/VB
#   you/PRP
#   (NP the/DT position/NN)
#   of/IN
#   DATA/NNP
#   SCIENTIST/NNP
#   for/IN
#   our/PRP$
#   (NP organization/NN)
#   We/PRP
#   are/VBP
#   excited/VBN
#   about/IN
#   (NP the/DT potential/NN)
#   that/IN
#   you/PRP
#   bring/VBP
#   to/TO
#   our/PRP$
#   (NP company.As/NN)
#   we/PRP
#   discussed/VBD
#   during/IN
#   your/PRP$
#   interviews/NNS
#   you/PRP
#   will/MD
#   be/VB
#   working/VBG
#   in/IN
#   our/PRP$
#   (NP north/JJ city/NN)
#   (NP regional/JJ office/NN)
#   where/WRB
#   our/PRP$
#   DATA/NNP
#   and/CC
#   (NP customer/NN)
#   (NP service/NN)
#   departments/NNS
#   are/VBP
#   located/VBN
#   You/PRP
#   will/MD
#   report/VB
# ...

# %%
grammar = r"""
  NP:
    {<.*>+}          # Chunk everything
    }<VBD|IN>+{      # Chink sequences of VBD and IN
  """
cp = nltk.RegexpParser(grammar)
print(cp.parse(result))
# Out:
# (S
#   (NP
#     (NP Company/NN)
#     Job/NNP
#     Offer/NNP
#     Letter/NNP
#     Date:01/01/2019/NNP
#     Ms./NNP
#     Monu/NNP
#     (NP kumar/NN)
#     Address/NNP
#     Banglore/NNP
#     karnataka/NNP)
#   Dear/IN
#   (NP
#     Ms./NNP
#     Monu/NNP
#     (NP kumar/NN)
#     FACEBOOK/NNP
#     is/VBZ
#     pleased/VBN
#     to/TO
#     offer/VB
#     you/PRP
#     (NP the/DT position/NN))
#   of/IN
#   (NP DATA/NNP SCIENTIST/NNP)
#   for/IN
#   (NP our/PRP$ (NP organization/NN) We/PRP are/VBP excited/VBN)
#   about/IN
#   (NP (NP the/DT potential/NN))
#   that/IN
#   (NP you/PRP bring/VBP to/TO our/PRP$ (NP company.As/NN) we/PRP)
#   discussed/VBD
#   during/IN
#   (NP your/PRP$ interviews/NNS you/PRP will/MD be/VB working/VBG)
#   in/IN
#   (NP
#     our/PRP$
#     (NP north/JJ city/NN)
#     (NP regional/JJ office/NN)
#     where/WRB
#     our/PRP$
#     DATA/NNP
#     and/CC
#     (NP customer/NN)
#     (NP service/NN)
#     departments/NNS
#     are/VBP
# ...

# %%
grammar = r"""
  NP: {<DT|JJ|NN.*>+}          # Chunk sequences of DT, JJ, NN
  PP: {<IN><NP>}               # Chunk prepositions followed by NP
  VP: {<VB.*><NP|PP|CLAUSE>+$} # Chunk verbs and their arguments
  CLAUSE: {<NP><VP>}           # Chunk NP, VP
  """
cp = nltk.RegexpParser(grammar)
print(cp.parse(result))
# Out:
# (S
#   (NP Company/NN)
#   (NP
#     Job/NNP
#     Offer/NNP
#     Letter/NNP
#     Date:01/01/2019/NNP
#     Ms./NNP
#     Monu/NNP)
#   (NP kumar/NN)
#   (NP Address/NNP Banglore/NNP karnataka/NNP)
#   (PP Dear/IN (NP Ms./NNP Monu/NNP))
#   (NP kumar/NN)
#   (NP FACEBOOK/NNP)
#   is/VBZ
#   pleased/VBN
#   to/TO
#   offer/VB
#   you/PRP
#   (NP the/DT position/NN)
#   (PP of/IN (NP DATA/NNP SCIENTIST/NNP))
#   for/IN
#   our/PRP$
#   (NP organization/NN)
#   We/PRP
#   are/VBP
#   excited/VBN
#   (PP about/IN (NP the/DT potential/NN))
#   that/IN
#   you/PRP
#   bring/VBP
#   to/TO
#   our/PRP$
#   (NP company.As/NN)
#   we/PRP
#   discussed/VBD
#   during/IN
#   your/PRP$
#   (NP interviews/NNS)
#   you/PRP
#   will/MD
#   be/VB
#   working/VBG
#   in/IN
#   our/PRP$
#   (NP north/JJ city/NN)
#   (NP regional/JJ office/NN)
#   where/WRB
#   our/PRP$
#   (NP DATA/NNP)
#   and/CC
#   (NP customer/NN)
#   (NP service/NN)
#   (NP departments/NNS)
#   are/VBP
#   located/VBN
# ...

# %%
cp = nltk.RegexpParser(grammar, loop=2)
cp.parse(result)
# Out:
# Tree('S', [Tree('NP', [('Company', 'NN')]), Tree('NP', [('Job', 'NNP'), ('Offer', 'NNP'), ('Letter', 'NNP'), ('Date:01/01/2019', 'NNP'), ('Ms.', 'NNP'), ('Monu', 'NNP')]), Tree('NP', [('kumar', 'NN')]), Tree('NP', [('Address', 'NNP'), ('Banglore', 'NNP'), ('karnataka', 'NNP')]), Tree('PP', [('Dear', 'IN'), Tree('NP', [('Ms.', 'NNP'), ('Monu', 'NNP')])]), Tree('NP', [('kumar', 'NN')]), Tree('NP', [('FACEBOOK', 'NNP')]), ('is', 'VBZ'), ('pleased', 'VBN'), ('to', 'TO'), ('offer', 'VB'), ('you', 'PRP'), Tree('NP', [('the', 'DT'), ('position', 'NN')]), Tree('PP', [('of', 'IN'), Tree('NP', [('DATA', 'NNP'), ('SCIENTIST', 'NNP')])]), ('for', 'IN'), ('our', 'PRP$'), Tree('NP', [('organization', 'NN')]), ('We', 'PRP'), ('are', 'VBP'), ('excited', 'VBN'), Tree('PP', [('about', 'IN'), Tree('NP', [('the', 'DT'), ('potential', 'NN')])]), ('that', 'IN'), ('you', 'PRP'), ('bring', 'VBP'), ('to', 'TO'), ('our', 'PRP$'), Tree('NP', [('company.As', 'NN')]), ('we', 'PRP'), ('discussed', 'VBD'), ('durin
# ...

# %%
tree1 = nltk.Tree('NP', ['JOB','offer','letter','Date:01/01/2019'])

# %%
print(tree1)
# Out:
# (NP JOB offer letter Date:01/01/2019)

# %%
tree2=nltk.Tree('NP',['Ms.','Monu','kumar'])
print(tree2)
# Out:
# (NP Ms. Monu kumar)

# %%
tree3=nltk.Tree('NP',['Address','Bangalore','karnataka'])
print(tree3)
# Out:
# (NP Address Bangalore karnataka)

# %%
tree4=nltk.Tree('NP',['Company','FACEBOOK'])
print(tree4)
# Out:
# (NP Company FACEBOOK)

# %%
tree5=nltk.Tree('NP',['Position','DATA','SCIENTIST'])
print(tree5)
# Out:
# (NP Position DATA SCIENTIST)

# %%
tree6=nltk.Tree('NP',['Director','Ms.','RAJ'])
print(tree6)
# Out:
# (NP Director Ms. RAJ)

# %%
print(tree1)
print(tree2)
print(tree3)
print(tree4)
print(tree5)
print(tree6)
tree1.draw()
tree2.draw()
tree3.draw()
tree4.draw()
tree5.draw()
tree6.draw()
# Out:
# (NP JOB offer letter Date:01/01/2019)
# (NP Ms. Monu kumar)
# (NP Address Bangalore karnataka)
# (NP Company FACEBOOK)
# (NP Position DATA SCIENTIST)
# (NP Director Ms. RAJ)

# %%
tree7=('s',[tree1,tree2,tree3,tree4,tree5,tree6])

# %%
print(tree7)
# Out:
# ('s', [Tree('NP', ['JOB', 'offer', 'letter', 'Date:01/01/2019']), Tree('NP', ['Ms.', 'Monu', 'kumar']), Tree('NP', ['Address', 'Bangalore', 'karnataka']), Tree('NP', ['Company', 'FACEBOOK']), Tree('NP', ['Position', 'DATA', 'SCIENTIST']), Tree('NP', ['Director', 'Ms.', 'RAJ'])])
